# %%
import pandas as pd

# %%
import requests

url = "https://wheresthejump.com/full-movie-list"

r = requests.get(url)

dfs = pd.read_html(r.text)

# %%
dfs[0]
# Out:
#                                         Movie Name  \
# 0                              10 Cloverfield Lane
# 1                                    28 Days Later
# 2                                   28 Weeks Later
# 3                                 30 Days of Night
# 4                                               31
# 5                                   47 Meters Down
# 6                                             1408
# 7                                             1922
# 8                              A Cure for Wellness
# 9                                    A Ghost Story
# 10                A Girl Walks Home Alone at Night
# 11                       A Nightmare on Elm Street
# 12                       A Nightmare on Elm Street
# 13   A Nightmare on Elm Street 2: Freddy's Revenge
# 14     A Nightmare on Elm Street 3: Dream Warriors
# 15                                   A Quiet Place
# 16                           A Tale of Two Sisters
# ...

# %%
df = pd.DataFrame(dfs[0])

# %%
df.head()
# Out:
#             Movie Name                 Director  Year  Jump Count  \
# 0  10 Cloverfield Lane         Dan Trachtenberg  2016           8
# 1        28 Days Later              Danny Boyle  2003          10
# 2       28 Weeks Later  Juan Carlos Fresnadillo  2007          17
# 3     30 Days of Night              David Slade  2007           9
# 4                   31               Rob Zombie  2016           8
#
#    Jump Scare Rating Netflix (US)  Imdb
# 0                2.5           No   7.2
# 1                3.0           No   7.6
# 2                3.5           No   7.0
# 3                2.5           No   6.6
# 4                2.5           No   5.1

# %%
#df.to_excel(r'/Users/scarstruck/Downloads/horror_movies.xlsx', header = True)

# %%
df['Movie Name'].count()
# Out:
# 544
